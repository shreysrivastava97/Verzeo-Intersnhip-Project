# %% [markdown]
# ### Name: Shrey Srivastava

# %% [markdown]
# ### Batch: 3

# %% [markdown]
# ### Group: ML043B11

# %% [markdown]
# # Major Project - Predicting Prices Of Used Cars

# %% [markdown]
# ## Importing Libraries

# %%
# basic manipulation and formation of data frames 
import pandas as pd
import numpy as np

# visaulization libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# modelling libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# model evaluation libraries
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Importing  the data set

# %%
df = pd.read_excel('Data_Train.xlsx')
print('The shape of the data frame is {}. It is shown below'.format(df.shape))
df.head()
# Out:
# The shape of the data frame is (6019, 12). It is shown below
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# ## Cleaning the data

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# dtype: object

# %% [markdown]
# Now Mileage, Engine and Power have numerical values, therefore we will change there type. But the units have to be removed first.

# %% [markdown]
# ### Removing units

# %% [markdown]
# #### Engine

# %%
new_list_engine = []
for engine in df['Engine']:
    string=str(engine)
    rep=string.replace('CC','')
    new_list_engine.append(rep)
    
new_list_engine
    
df.insert(8, 'Engine (CC)', new_list_engine)
df.drop(['Engine'], axis=1, inplace=True)
    
    
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage Engine (CC)      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg        998   58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl       1582   126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl       1199    88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl       1248   88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl       1968   140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# #### Power

# %%
new_list_power = []
for power in df['Power']:
    string=str(power)
    rep=string.replace('bhp','')
    new_list_power.append(rep)
    
new_list_power
    
df.insert(9, 'Power (bhp)', new_list_power)
df.drop('Power', axis=1, inplace=True)
    
    
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage Engine (CC) Power (bhp)  \
# 0       CNG       Manual      First  26.6 km/kg        998       58.16
# 1    Diesel       Manual      First  19.67 kmpl       1582       126.2
# 2    Petrol       Manual      First   18.2 kmpl       1199        88.7
# 3    Diesel       Manual      First  20.77 kmpl       1248       88.76
# 4    Diesel    Automatic     Second   15.2 kmpl       1968       140.8
#
#    Seats  Price
# 0    5.0   1.75
# 1    5.0  12.50
# 2    5.0   4.50
# 3    7.0   6.00
# 4    5.0  17.74

# %% [markdown]
# #### Mileage

# %% [markdown]
# From a naked eye it appears that there are two different units mentioned, 'km/kg' and 'kmpl'. We will try to find out how many different units are there.

# %%
df_mileage1 = pd.DataFrame(df['Mileage'].str.contains(pat='km/kg'))
df_mileage1['Mileage'].value_counts()
# Out:
# False    5951
# True       66
# Name: Mileage, dtype: int64

# %%
df_mileage2 = pd.DataFrame(df['Mileage'].str.contains(pat='kmpl'))
df_mileage2['Mileage'].value_counts()
# Out:
# True     5951
# False      66
# Name: Mileage, dtype: int64

# %% [markdown]
# From the results above we can see that there are only two units mentioned kmpl which is mentioned for 5951 observations, and km/kg which is mentioned for the remaining 66 observations. Let us remove them too. Since there are two types of measurements due to different kinds of fuels, we will call the mileage variable 'Mileage/unit'.

# %%
new_list_mileage = []

for mileage in df['Mileage']:
    string=str(mileage)
    
    if 'kmpl'in string:
        rep=string.replace('kmpl','')
        new_list_mileage.append(rep)
    
    else:
        rep=string.replace('km/kg','')
        new_list_mileage.append(rep)
                        

        
        
new_list_mileage
    
df.insert(7, 'Mileage/unit', new_list_mileage)
df.drop('Mileage', axis=1, inplace=True)
    
    
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type Mileage/unit Engine (CC) Power (bhp)  \
# 0       CNG       Manual      First        26.6         998       58.16
# 1    Diesel       Manual      First       19.67        1582       126.2
# 2    Petrol       Manual      First        18.2        1199        88.7
# 3    Diesel       Manual      First       20.77        1248       88.76
# 4    Diesel    Automatic     Second        15.2        1968       140.8
#
#    Seats  Price
# 0    5.0   1.75
# 1    5.0  12.50
# 2    5.0   4.50
# 3    7.0   6.00
# 4    5.0  17.74

# %% [markdown]
# Now we will convert the required columns to numerical types

# %% [markdown]
# ### Changing type

# %%
df[["Mileage/unit"]] = df[["Mileage/unit"]].astype("float")
df[["Engine (CC)"]] = df[["Engine (CC)"]].astype("float")

# %%
df["Power (bhp)"] = pd.to_numeric(df["Power (bhp)"], errors='coerce')

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage/unit         float64
# Engine (CC)          float64
# Power (bhp)          float64
# Seats                float64
# Price                float64
# dtype: object

# %% [markdown]
# ### After changing the types, we can now deal with the missing values, let's look at the missing values

# %%
df.isnull().sum()
# Out:
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage/unit           2
# Engine (CC)           36
# Power (bhp)          143
# Seats                 42
# Price                  0
# dtype: int64

# %% [markdown]
# To deal with the appropriate means, we need to eliminate the outliers first

# %% [markdown]
# ### Examining outliers

# %% [markdown]
# #### Engine

# %%
sns.boxplot(x='Engine (CC)', data=df)

# %%
df[df['Engine (CC)']>=3000]
# Out:
#                                              Name    Location  Year  \
# 70                Porsche Cayenne 2009-2014 Turbo      Mumbai  2008
# 152         Mercedes-Benz S Class 2005 2013 S 500     Kolkata  2010
# 459            Audi Q7 4.2 TDI Quattro Technology  Coimbatore  2016
# 586            Audi Q7 4.2 TDI Quattro Technology       Kochi  2014
# 589       Mercedes-Benz S Class 2005 2013 S 350 L   Bangalore  2006
# ...                                           ...         ...   ...
# 5728  Mercedes-Benz E-Class 2009-2013 E350 Petrol     Kolkata  2009
# 5781                   Lamborghini Gallardo Coupe       Delhi  2011
# 5885       Mercedes-Benz R-Class R350 4Matic Long        Pune  2010
# 5919                       Jaguar F Type 5.0 V8 S   Hyderabad  2015
# 6011                      Skoda Superb 3.6 V6 FSI   Hyderabad  2009
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage/unit  \
# 70                73000    Petrol    Automatic      First          8.50
# 152               35277    Petrol    Automatic      First          7.81
# 459               51002    Diesel    Automatic      First         11.33
# 586               79926    Diesel    Automatic      First         11.33
# 589               47088    Petrol    Automatic     Second         10.13
# ...                 ...       ...          ...        ...           ...
# 5728              43600    Petrol    Automatic      First         10.93
# 5781               6500    Petrol    Automatic      Third          6.40
# 5885              93000    Petrol    Automatic     Second         11.80
# 5919               8000    Petrol    Automatic      First         12.50
# 6011              53000    Petrol    Automatic      First          0.00
#
#       Engine (CC)  Power (bhp)  Seats   Price
# 70         4806.0        500.0    5.0   14.50
# 152        5461.0        362.9    5.0   30.00
# 459        4134.0        335.2    7.0   48.91
# 586        4134.0        335.2    7.0   29.77
# 589        3498.0        364.9    5.0   19.00
# ...           ...          ...    ...     ...
# 5728       3498.0        272.0    5.0   10.24
# 5781       5204.0        560.0    2.0  120.00
# 5885       3498.0        272.0    7.0   15.00
# 5919       5000.0        488.1    2.0  100.00
# 6011       3597.0        262.6    5.0    4.75
#
# [61 rows x 12 columns]

# %% [markdown]
# #### Power

# %%
sns.boxplot(x='Power (bhp)', data=df)

# %%
df[df['Power (bhp)']>=230]
# Out:
#                                       Name    Location  Year  \
# 38        Mercedes-Benz M-Class ML 350 CDI        Pune  2013
# 70         Porsche Cayenne 2009-2014 Turbo      Mumbai  2008
# 103        Audi A4 3.0 TDI Quattro Premium     Kolkata  2010
# 107   Jaguar XF 3.0 Litre S Premium Luxury   Hyderabad  2011
# 134               Mercedes-Benz SLC 43 AMG     Kolkata  2017
# ...                                    ...         ...   ...
# 5919                Jaguar F Type 5.0 V8 S   Hyderabad  2015
# 5927    Audi Q5 3.0 TDI Quattro Technology  Coimbatore  2018
# 5946   BMW 5 Series 2013-2017 530d M Sport   Bangalore  2016
# 6008               Porsche Panamera Diesel   Hyderabad  2013
# 6011               Skoda Superb 3.6 V6 FSI   Hyderabad  2009
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage/unit  \
# 38                85000    Diesel    Automatic      First         11.74
# 70                73000    Petrol    Automatic      First          8.50
# 103               30000    Diesel    Automatic      First         14.94
# 107               78000    Diesel    Automatic     Second         14.74
# 134               13372    Petrol    Automatic      First         19.00
# ...                 ...       ...          ...        ...           ...
# 5919               8000    Petrol    Automatic      First         12.50
# 5927              29091    Diesel    Automatic      First         13.22
# 5946              16000    Diesel    Automatic      First         14.69
# 6008              40000    Diesel    Automatic     Second         17.85
# 6011              53000    Petrol    Automatic      First          0.00
#
#       Engine (CC)  Power (bhp)  Seats   Price
# 38         2987.0       254.80    5.0   28.00
# 70         4806.0       500.00    5.0   14.50
# 103        2967.0       241.40    5.0    9.80
# 107        2993.0       270.90    5.0   24.00
# 134        2996.0       362.07    2.0   54.00
# ...           ...          ...    ...     ...
# 5919       5000.0       488.10    2.0  100.00
# 5927       2967.0       241.40    5.0   45.52
# 5946       2993.0       258.00    5.0   48.00
# 6008       2967.0       300.00    4.0   45.00
# 6011       3597.0       262.60    5.0    4.75
#
# [239 rows x 12 columns]

# %% [markdown]
# #### Mileage

# %%
sns.boxplot(x='Mileage/unit', data=df)

# %% [markdown]
# Here the outliers below the lower bound are isolated, therefore we will remove them as usual

# %%
df= df[df['Mileage/unit']>=5]

# %%
df[df['Mileage/unit']>=29]
# Out:
#                                    Name Location  Year  Kilometers_Driven  \
# 1269  Maruti Alto 800 2016-2019 CNG LXI   Mumbai  2018              10600
# 1332             Maruti Wagon R CNG LXI     Pune  2013              79494
# 2059             Maruti Wagon R CNG LXI   Mumbai  2013              54000
# 2371             Maruti Wagon R CNG LXI     Pune  2014              29202
# 2701          Maruti Celerio CNG VXI MT    Kochi  2016              70536
# 3119   Maruti Alto K10 LXI CNG Optional    Kochi  2018              44202
# 3129             Maruti Wagon R CNG LXI    Delhi  2014              74663
# 3553  Maruti Alto 800 2016-2019 CNG LXI     Pune  2015              18000
# 3869  Maruti Alto 800 2016-2019 CNG LXI    Delhi  2012              65537
# 4141             Maruti Wagon R CNG LXI   Mumbai  2014              47200
# 4769  Maruti Alto 800 2016-2019 CNG LXI    Kochi  2017              24310
# 5178          Maruti Celerio CNG VXI MT    Delhi  2015              64687
# 5710            Maruti Alto 800 CNG LXI   Mumbai  2013              26200
# 5935            Maruti Alto K10 LXI CNG     Pune  2015              59525
#
#      Fuel_Type Transmission Owner_Type  Mileage/unit  Engine (CC)  \
# 1269       CNG       Manual      First         33.44        796.0
# 1332       CNG       Manual      First         33.54        998.0
# 2059       CNG       Manual      First         33.54        998.0
# 2371       CNG       Manual      First         33.54        998.0
# 2701       CNG       Manual      First         31.79        998.0
# 3119       CNG       Manual      First         32.26        998.0
# 3129       CNG       Manual      First         33.54        998.0
# 3553       CNG       Manual      First         33.44        796.0
# 3869       CNG       Manual     Second         33.44        796.0
# 4141       CNG       Manual      First         33.54        998.0
# 4769       CNG       Manual      First         33.44        796.0
# 5178       CNG       Manual      First         31.79        998.0
# 5710       CNG       Manual      First         30.46        796.0
# 5935       CNG       Manual     Second         32.26        998.0
#
#       Power (bhp)  Seats  Price
# 1269        40.30    4.0   3.50
# 1332        67.04    5.0   2.96
# 2059        67.04    5.0   3.05
# 2371        67.04    5.0   3.90
# 2701        58.33    5.0   4.58
# 3119        58.20    4.0   4.00
# 3129        67.04    5.0   3.25
# 3553        40.30    4.0   3.00
# 3869        40.30    4.0   2.10
# 4141        67.04    5.0   2.85
# 4769        40.30    4.0   3.70
# 5178        58.33    5.0   3.80
# 5710        47.30    5.0   2.15
# 5935        58.20    4.0   3.10

# %% [markdown]
# #### Seats

# %%
sns.boxplot(x='Seats',data=df)

# %%
df[df['Seats']>8]
# Out:
#                                        Name   Location  Year  \
# 814                     Toyota Qualis FS B2       Pune  2004
# 917                            Tata Sumo DX     Mumbai  2013
# 1347              Mahindra Scorpio LX BS IV  Bangalore  2007
# 1907                    Toyota Qualis FS B3  Bangalore  2002
# 2312        Chevrolet Tavera LT 9 Str BS IV    Kolkata  2012
# 2359                  Mahindra Xylo D2 Maxx    Chennai  2016
# 2575  Chevrolet Tavera LS B3 10 Seats BSIII  Hyderabad  2015
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage/unit  \
# 814               77757    Diesel       Manual     Second         13.10
# 917               20000    Diesel       Manual      First         14.07
# 1347              74112    Diesel       Manual      First         12.05
# 1907              63000    Diesel       Manual      Third         13.10
# 2312              67132    Diesel       Manual      First         13.58
# 2359             150000    Diesel       Manual      First         14.95
# 2575             120000    Diesel       Manual      First         14.80
#
#       Engine (CC)  Power (bhp)  Seats  Price
# 814        2446.0         75.0   10.0   3.50
# 917        1978.0         83.1   10.0   5.25
# 1347       2179.0        120.0    9.0   4.10
# 1907       2446.0         75.0   10.0   3.65
# 2312       2499.0         78.0    9.0   4.75
# 2359       2489.0         93.7    9.0   4.50
# 2575       2499.0         80.0   10.0   5.50

# %% [markdown]
# #### Price

# %%
sns.boxplot(x='Price', data=df)

# %%
df[df['Price']>80]
# Out:
#                                              Name    Location  Year  \
# 1505              Land Rover Range Rover Sport SE       Kochi  2019
# 1974                           BMW 7 Series 740Li  Coimbatore  2018
# 1984                           BMW 7 Series 740Li   Bangalore  2017
# 2095                     Mercedes-Benz SLC 43 AMG  Coimbatore  2019
# 4079  Land Rover Range Rover 3.0 Diesel LWB Vogue   Hyderabad  2017
# 4691               Mercedes-Benz SLK-Class 55 AMG   Bangalore  2014
# 5535                    BMW X6 xDrive 40d M Sport   Ahmedabad  2015
# 5781                   Lamborghini Gallardo Coupe       Delhi  2011
# 5919                       Jaguar F Type 5.0 V8 S   Hyderabad  2015
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage/unit  \
# 1505              26013    Diesel    Automatic      First         12.65
# 1974              28060    Petrol    Automatic      First         12.05
# 1984              17465    Petrol    Automatic      First         12.05
# 2095               2526    Petrol    Automatic      First         19.00
# 4079              25000    Diesel    Automatic      First         13.33
# 4691               3000    Petrol    Automatic     Second         12.00
# 5535              97003    Diesel    Automatic      First         15.87
# 5781               6500    Petrol    Automatic      Third          6.40
# 5919               8000    Petrol    Automatic      First         12.50
#
#       Engine (CC)  Power (bhp)  Seats   Price
# 1505       2993.0       255.00    5.0   97.07
# 1974       2979.0       320.00    5.0   93.67
# 1984       2979.0       320.00    5.0   93.00
# 2095       2996.0       362.07    2.0   83.96
# 4079       2993.0       255.00    5.0  160.00
# 4691       5461.0       421.00    2.0   90.00
# 5535       2993.0       308.43    5.0   85.00
# 5781       5204.0       560.00    2.0  120.00
# 5919       5000.0       488.10    2.0  100.00

# %% [markdown]
# Now for all the columns above, the outliers shown in the boxplots  are not true outliers, since the distribution of car data is not a normal distribution. There is a huge disparity in the Price, Engine and Power of cars depending on the make. This also becomes clear after using domain knowledge about cars and researching about the prices and other variables of these outlier data points. The values marked as outliers in boxplots are actually correct

# %% [markdown]
# To solve this problem and find the true outliers, we will try to remove this disparity by creating new categorical variables; 'Engine_Class' and 'Power_Segment'. These categorical variables take into account the segment of the car.

# %% [markdown]
# Now, using our domain knowledge about cars, we find that certain variables in this data are functions of other variables.

# %% [markdown]
# First we will try to find the outliers in 'Mileage/unit' by grouping it based on 'Fuel_Type' as mileage is a function of the type of fuel

# %%
sns.boxplot(x='Fuel_Type', y='Mileage/unit',data=df)

# %% [markdown]
# Let's inspect the values which appear to be outliers

# %%
check1 = df.loc[df['Fuel_Type']=='CNG']
check1 = check1[check1['Mileage/unit']<=15]
check1
# Out:
#                                 Name   Location  Year  Kilometers_Driven  \
# 893     Hyundai Accent Executive CNG  Hyderabad  2010              95637
# 3901  Toyota Corolla Altis 1.8 G CNG     Mumbai  2010              63000
#
#      Fuel_Type Transmission Owner_Type  Mileage/unit  Engine (CC)  \
# 893        CNG       Manual     Second         13.20       1495.0
# 3901       CNG       Manual     Second         14.53       1798.0
#
#       Power (bhp)  Seats  Price
# 893          93.7    5.0   1.90
# 3901        138.0    5.0   3.35

# %%
check2 = df.loc[df['Fuel_Type']=='Petrol']
check2 = check2[check2['Mileage/unit']<=7]
check2
# Out:
#                             Name Location  Year  Kilometers_Driven Fuel_Type  \
# 5781  Lamborghini Gallardo Coupe    Delhi  2011               6500    Petrol
#
#      Transmission Owner_Type  Mileage/unit  Engine (CC)  Power (bhp)  Seats  \
# 5781    Automatic      Third           6.4       5204.0        560.0    2.0
#
#       Price
# 5781  120.0

# %% [markdown]
# These values are also correct, therefore they are not outliers

# %% [markdown]
# Now as mentioned earlier, we will create categorical variables

# %% [markdown]
# ### Creating Categorical Variables

# %%
bins_bhp = np.linspace(df['Power (bhp)'].min(), df['Power (bhp)'].max(), 5)
df['Power_Segment'] = pd.cut(df['Power (bhp)'], bins=bins_bhp, labels=['Low', 'Medium', 'High', 'Very High'], include_lowest=True)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type  Mileage/unit  Engine (CC)  \
# 0          CNG       Manual      First         26.60        998.0
# 1       Diesel       Manual      First         19.67       1582.0
# 2       Petrol       Manual      First         18.20       1199.0
# 3       Diesel       Manual      First         20.77       1248.0
# 4       Diesel    Automatic     Second         15.20       1968.0
# ...        ...          ...        ...           ...          ...
# 6014    Diesel       Manual      First         28.40       1248.0
# 6015    Diesel       Manual      First         24.40       1120.0
# 6016    Diesel       Manual     Second         14.00       2498.0
# 6017    Petrol       Manual      First         18.90        998.0
# 6018    Diesel       Manual      First         25.44        936.0
#
#       Power (bhp)  Seats  Price Power_Segment
# 0           58.16    5.0   1.75           Low
# 1          126.20    5.0  12.50           Low
# 2           88.70    5.0   4.50           Low
# 3           88.76    7.0   6.00           Low
# 4          140.80    5.0  17.74           Low
# ...           ...    ...    ...           ...
# 6014        74.00    5.0   4.75           Low
# 6015        71.00    5.0   4.00           Low
# 6016       112.00    8.0   2.90           Low
# 6017        67.10    5.0   2.65           Low
# 6018        57.60    5.0   2.50           Low
#
# [5949 rows x 13 columns]

# %%
bins_cc = np.linspace(df['Engine (CC)'].min(), df['Engine (CC)'].max(), 5)
df['Engine_Class'] = pd.cut(df['Engine (CC)'], bins=bins_cc, labels=['Small', 'Medium', 'Large', 'Mega'], include_lowest=True)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type  Mileage/unit  Engine (CC)  \
# 0          CNG       Manual      First         26.60        998.0
# 1       Diesel       Manual      First         19.67       1582.0
# 2       Petrol       Manual      First         18.20       1199.0
# 3       Diesel       Manual      First         20.77       1248.0
# 4       Diesel    Automatic     Second         15.20       1968.0
# ...        ...          ...        ...           ...          ...
# 6014    Diesel       Manual      First         28.40       1248.0
# 6015    Diesel       Manual      First         24.40       1120.0
# 6016    Diesel       Manual     Second         14.00       2498.0
# 6017    Petrol       Manual      First         18.90        998.0
# 6018    Diesel       Manual      First         25.44        936.0
#
#       Power (bhp)  Seats  Price Power_Segment Engine_Class
# 0           58.16    5.0   1.75           Low        Small
# 1          126.20    5.0  12.50           Low        Small
# 2           88.70    5.0   4.50           Low        Small
# 3           88.76    7.0   6.00           Low        Small
# 4          140.80    5.0  17.74           Low       Medium
# ...           ...    ...    ...           ...          ...
# 6014        74.00    5.0   4.75           Low        Small
# 6015        71.00    5.0   4.00           Low        Small
# 6016       112.00    8.0   2.90           Low       Medium
# 6017        67.10    5.0   2.65           Low        Small
# 6018        57.60    5.0   2.50           Low        Small
#
# [5949 rows x 14 columns]

# %% [markdown]
# Here we will try finding outliers in 'Power (bhp)' based on 'Engine_Class', as the power of a car depends on its engine size

# %%
sns.boxplot(x='Engine_Class', y='Power (bhp)', data=df)

# %% [markdown]
# Let's inspect the values which appear to be outliers

# %%
check3 = df.loc[df['Engine_Class']=='Medium']
check3 = check3[check3['Power (bhp)']>=400]
check3
# Out:
#                 Name Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 148   Audi RS5 Coupe   Mumbai  2013              23000    Petrol    Automatic
# 4061  Audi RS5 Coupe   Mumbai  2013              23312    Petrol    Automatic
#
#      Owner_Type  Mileage/unit  Engine (CC)  Power (bhp)  Seats  Price  \
# 148       First         11.05       2894.0        444.0    4.0   37.0
# 4061      First         11.05       2894.0        444.0    4.0   40.5
#
#      Power_Segment Engine_Class
# 148      Very High       Medium
# 4061     Very High       Medium

# %%
check4 = df.loc[df['Engine_Class']=='Large']
check4 = check4[check4['Power (bhp)']>=400]
check4
# Out:
#                               Name Location  Year  Kilometers_Driven  \
# 3341  BMW 7 Series 2007-2012 750Li    Kochi  2010              50161
# 4627       BMW 6 Series 650i Coupe    Kochi  2010              65329
# 4821       BMW 6 Series 630i Coupe   Mumbai  2011               5900
#
#      Fuel_Type Transmission Owner_Type  Mileage/unit  Engine (CC)  \
# 3341    Petrol    Automatic      First          8.77       4395.0
# 4627    Petrol    Automatic      First          7.94       4395.0
# 4821    Petrol    Automatic      First          7.94       4395.0
#
#       Power (bhp)  Seats  Price Power_Segment Engine_Class
# 3341        402.0    5.0  25.93          High        Large
# 4627        450.0    4.0  20.72     Very High        Large
# 4821        450.0    4.0  47.50     Very High        Large

# %% [markdown]
# These values are also correct and not outliers

# %% [markdown]
# Finally, as price of the car is a function of its engine size and power, we try finding the outliers in 'Price' based on the 'Engine_Class' and 'Power_Segment'

# %%
sns.boxplot(x='Engine_Class', y='Price', hue='Power_Segment', data=df)

# %% [markdown]
# Let's inspect the values which appear to be outliers

# %%
check5 = df.loc[df['Engine_Class']=='Small']
check5 = check5[check5['Power_Segment']=='Medium']
check5 = check5[check5['Price']>=40]
check5
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 473   Mercedes-Benz E-Class E 220 d    Kochi  2018              26405
# 1113  Mercedes-Benz E-Class E 220 d    Kochi  2018              20446
# 2509  Mercedes-Benz E-Class E 220 d   Mumbai  2018              11000
# 3836         Audi A6 35 TFSI Matrix    Delhi  2018              22000
#
#      Fuel_Type Transmission Owner_Type  Mileage/unit  Engine (CC)  \
# 473     Petrol    Automatic      First         12.60       1950.0
# 1113    Petrol    Automatic      First         12.60       1950.0
# 2509    Diesel    Automatic      First         16.10       1950.0
# 3836    Petrol    Automatic      First         15.26       1798.0
#
#       Power (bhp)  Seats  Price Power_Segment Engine_Class
# 473        191.34    5.0  51.43        Medium        Small
# 1113       191.34    5.0  51.35        Medium        Small
# 2509       194.00    5.0  56.50        Medium        Small
# 3836       187.74    5.0  41.50        Medium        Small

# %%
check6 = df.loc[df['Engine_Class']=='Medium']
check6 = check6[check6['Power_Segment']=='Medium']
check6 = check6[check6['Price']>=140]
check6
# Out:
#                                              Name   Location  Year  \
# 4079  Land Rover Range Rover 3.0 Diesel LWB Vogue  Hyderabad  2017
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage/unit  \
# 4079              25000    Diesel    Automatic      First         13.33
#
#       Engine (CC)  Power (bhp)  Seats  Price Power_Segment Engine_Class
# 4079       2993.0        255.0    5.0  160.0        Medium       Medium

# %% [markdown]
# These values are also accurate

# %% [markdown]
# Hence our initial prognosis of outliers not being true outliers and in turn being accurate data, turns out to be correct

# %% [markdown]
# Now we will replace the missing values

# %% [markdown]
# ### Replacing missing values

# %%
df.isnull().sum()
# Out:
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage/unit           0
# Engine (CC)           25
# Power (bhp)          104
# Seats                 30
# Price                  0
# Power_Segment        104
# Engine_Class          25
# dtype: int64

# %% [markdown]
# Since the data has a lot of outliers (according to the boxplot), it is better to replace the missing values with the median.

# %%
df['Engine (CC)'].replace(np.nan, df['Engine (CC)'].median(), inplace=True)
df['Power (bhp)'].replace(np.nan, df['Power (bhp)'].median(), inplace=True)
df['Seats'].replace(np.nan, df['Seats'].median(), inplace=True)

# %%
df['Mileage/unit'].replace(0, df['Mileage/unit'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Name                   0
# Location               0
# Year                   0
# Kilometers_Driven      0
# Fuel_Type              0
# Transmission           0
# Owner_Type             0
# Mileage/unit           0
# Engine (CC)            0
# Power (bhp)            0
# Seats                  0
# Price                  0
# Power_Segment        104
# Engine_Class          25
# dtype: int64

# %% [markdown]
# Let's check if there are any missing values left

# %% [markdown]
# Since we created two new variables, we will replace the missing values in 'Engine_Class' and 'Power_Segment' based on the range they fall in

# %%
bins_cc = np.linspace(df['Engine (CC)'].min(), df['Engine (CC)'].max(), 5)
df['Engine_Class'] = pd.cut(df['Engine (CC)'], bins=bins_cc, labels=['Small', 'Medium', 'Large', 'Mega'], include_lowest=True)
df[df['Engine_Class'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage/unit, Engine (CC), Power (bhp), Seats, Price, Power_Segment, Engine_Class]
# Index: []

# %%
bins_bhp = np.linspace(df['Power (bhp)'].min(), df['Power (bhp)'].max(), 5)
df['Power_Segment'] = pd.cut(df['Power (bhp)'], bins=bins_bhp, labels=['Low', 'Medium', 'High', 'Very High'], include_lowest=True)
df[df['Power_Segment'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Location, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage/unit, Engine (CC), Power (bhp), Seats, Price, Power_Segment, Engine_Class]
# Index: []

# %%
df.insert(9,'Engine_Class',df['Engine_Class'],allow_duplicates=True)

# %%
df.insert(11,'Power_Segment',df['Power_Segment'],allow_duplicates=True)

# %%
df = df.iloc[:,0:14]
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# ...                                ...         ...   ...                ...
# 6014                  Maruti Swift VDI       Delhi  2014              27365
# 6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 6016             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 6017                Maruti Wagon R VXI     Kolkata  2013              46000
# 6018             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
#      Fuel_Type Transmission Owner_Type  Mileage/unit  Engine (CC)  \
# 0          CNG       Manual      First         26.60        998.0
# 1       Diesel       Manual      First         19.67       1582.0
# 2       Petrol       Manual      First         18.20       1199.0
# 3       Diesel       Manual      First         20.77       1248.0
# 4       Diesel    Automatic     Second         15.20       1968.0
# ...        ...          ...        ...           ...          ...
# 6014    Diesel       Manual      First         28.40       1248.0
# 6015    Diesel       Manual      First         24.40       1120.0
# 6016    Diesel       Manual     Second         14.00       2498.0
# 6017    Petrol       Manual      First         18.90        998.0
# 6018    Diesel       Manual      First         25.44        936.0
#
#      Engine_Class  Power (bhp) Power_Segment  Seats  Price
# 0           Small        58.16           Low    5.0   1.75
# 1           Small       126.20           Low    5.0  12.50
# 2           Small        88.70           Low    5.0   4.50
# 3           Small        88.76           Low    7.0   6.00
# 4          Medium       140.80           Low    5.0  17.74
# ...           ...          ...           ...    ...    ...
# 6014        Small        74.00           Low    5.0   4.75
# 6015        Small        71.00           Low    5.0   4.00
# 6016       Medium       112.00           Low    8.0   2.90
# 6017        Small        67.10           Low    5.0   2.65
# 6018        Small        57.60           Low    5.0   2.50
#
# [5949 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage/unit         0
# Engine (CC)          0
# Engine_Class         0
# Power (bhp)          0
# Power_Segment        0
# Seats                0
# Price                0
# dtype: int64

# %% [markdown]
# As we can see no missing values left and all the proper outliers have been dealt with

# %% [markdown]
# #### Now the data is completely clean

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.to_csv('clean_data.csv', index=False)

# %%
df.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage/unit  Engine (CC) Engine_Class  \
# 0       CNG       Manual      First         26.60        998.0        Small
# 1    Diesel       Manual      First         19.67       1582.0        Small
# 2    Petrol       Manual      First         18.20       1199.0        Small
# 3    Diesel       Manual      First         20.77       1248.0        Small
# 4    Diesel    Automatic     Second         15.20       1968.0       Medium
#
#    Power (bhp) Power_Segment  Seats  Price
# 0        58.16           Low    5.0   1.75
# 1       126.20           Low    5.0  12.50
# 2        88.70           Low    5.0   4.50
# 3        88.76           Low    7.0   6.00
# 4       140.80           Low    5.0  17.74

# %% [markdown]
# Now the prices of old cars depend on how old they are. So let us create a column which tells us how old the car is.

# %%
df.insert(3, 'Years_Old', 2020 - df['Year'])
df.head()
# Out:
#                                Name    Location  Year  Years_Old  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010         10
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015          5
# 2                      Honda Jazz V     Chennai  2011          9
# 3                 Maruti Ertiga VDI     Chennai  2012          8
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013          7
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage/unit  \
# 0              72000       CNG       Manual      First         26.60
# 1              41000    Diesel       Manual      First         19.67
# 2              46000    Petrol       Manual      First         18.20
# 3              87000    Diesel       Manual      First         20.77
# 4              40670    Diesel    Automatic     Second         15.20
#
#    Engine (CC) Engine_Class  Power (bhp) Power_Segment  Seats  Price
# 0        998.0        Small        58.16           Low    5.0   1.75
# 1       1582.0        Small       126.20           Low    5.0  12.50
# 2       1199.0        Small        88.70           Low    5.0   4.50
# 3       1248.0        Small        88.76           Low    7.0   6.00
# 4       1968.0       Medium       140.80           Low    5.0  17.74

# %%
df.corr()
# Out:
#                        Year  Years_Old  Kilometers_Driven  Mileage/unit  \
# Year               1.000000  -1.000000          -0.170561      0.296718
# Years_Old         -1.000000   1.000000           0.170561     -0.296718
# Kilometers_Driven -0.170561   0.170561           1.000000     -0.064283
# Mileage/unit       0.296718  -0.296718          -0.064283      1.000000
# Engine (CC)       -0.057960   0.057960           0.092431     -0.645478
# Power (bhp)        0.020093  -0.020093           0.033366     -0.548240
# Seats              0.015860  -0.015860           0.081407     -0.343516
# Price              0.302463  -0.302463          -0.009048     -0.333263
#
#                    Engine (CC)  Power (bhp)     Seats     Price
# Year                 -0.057960     0.020093  0.015860  0.302463
# Years_Old             0.057960    -0.020093 -0.015860 -0.302463
# Kilometers_Driven     0.092431     0.033366  0.081407 -0.009048
# Mileage/unit         -0.645478    -0.548240 -0.343516 -0.333263
# Engine (CC)           1.000000     0.862351  0.396405  0.658130
# Power (bhp)           0.862351     1.000000  0.104426  0.773250
# Seats                 0.396405     0.104426  1.000000  0.055178
# Price                 0.658130     0.773250  0.055178  1.000000

# %%
df.corr()['Price']
# Out:
# Year                 0.302463
# Years_Old           -0.302463
# Kilometers_Driven   -0.009048
# Mileage/unit        -0.333263
# Engine (CC)          0.658130
# Power (bhp)          0.773250
# Seats                0.055178
# Price                1.000000
# Name: Price, dtype: float64

# %% [markdown]
# We can clearly see that:
# - as the car gets older, the price tends to go lower
# - more the kilometers driven, less the price, although the correlation is not that strong
# - more the Engine capacity and Power of the car, higher is the price
# - Mileage is inversely proportional to the price of cars. This maybe due to the fact that luxury cars have lesser mileage   and greater cost

# %% [markdown]
# We have mentioned earlier that there is a huge disparity in the prices of the cars. This is down to the make of the car. Luxury car makers like Audi, Porsche, Range Rover etc. have very expensive cars compared to economy section like Maruti or Tata

# %% [markdown]
# We will now try to create a categorical variable which is based on the make of the car

# %%
make = []
for name in df['Name']:
    make.append(name.split(' ')[0])

df.insert(1, 'Make', make)
df.head()
# Out:
#                                Name     Make    Location  Year  Years_Old  \
# 0            Maruti Wagon R LXI CNG   Maruti      Mumbai  2010         10
# 1  Hyundai Creta 1.6 CRDi SX Option  Hyundai        Pune  2015          5
# 2                      Honda Jazz V    Honda     Chennai  2011          9
# 3                 Maruti Ertiga VDI   Maruti     Chennai  2012          8
# 4   Audi A4 New 2.0 TDI Multitronic     Audi  Coimbatore  2013          7
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage/unit  \
# 0              72000       CNG       Manual      First         26.60
# 1              41000    Diesel       Manual      First         19.67
# 2              46000    Petrol       Manual      First         18.20
# 3              87000    Diesel       Manual      First         20.77
# 4              40670    Diesel    Automatic     Second         15.20
#
#    Engine (CC) Engine_Class  Power (bhp) Power_Segment  Seats  Price
# 0        998.0        Small        58.16           Low    5.0   1.75
# 1       1582.0        Small       126.20           Low    5.0  12.50
# 2       1199.0        Small        88.70           Low    5.0   4.50
# 3       1248.0        Small        88.76           Low    7.0   6.00
# 4       1968.0       Medium       140.80           Low    5.0  17.74

# %%
df['Make'].unique()
# Out:
# array(['Maruti', 'Hyundai', 'Honda', 'Audi', 'Nissan', 'Toyota',
#        'Volkswagen', 'Tata', 'Land', 'Mitsubishi', 'Renault',
#        'Mercedes-Benz', 'BMW', 'Mahindra', 'Ford', 'Porsche', 'Datsun',
#        'Jaguar', 'Volvo', 'Chevrolet', 'Skoda', 'Mini', 'Fiat', 'Jeep',
#        'Ambassador', 'Isuzu', 'ISUZU', 'Force', 'Bentley', 'Lamborghini'],
#       dtype=object)

# %%
df['Make'].replace('Land','Land Rover',inplace=True)
df['Make'].replace('Isuzu', 'ISUZU',inplace=True)

# %%
df['Make'].nunique()
# Out:
# 29

# %%
plt.figure(figsize=(60,60))
sns.swarmplot(x='Make', y='Price', data=df)

# %%
df_make = df[['Make', 'Price']]
df_make_plot = df_make.groupby('Make').mean()
df_make_plot
# Out:
#                     Price
# Make
# Ambassador       1.350000
# Audi            25.527234
# BMW             25.243146
# Bentley         59.000000
# Chevrolet        3.044463
# Datsun           3.049231
# Fiat             3.370000
# Force            9.333333
# Ford             6.900401
# Honda            5.428165
# Hyundai          5.447823
# ISUZU           14.696667
# Jaguar          37.632250
# Jeep            18.718667
# Lamborghini    120.000000
# Land Rover      42.526078
# Mahindra         8.055019
# Maruti           4.519926
# Mercedes-Benz   26.374412
# Mini            26.896923
# Mitsubishi      11.058889
# Nissan           4.738352
# Porsche         48.348333
# Renault          5.799034
# Skoda            7.584620
# Tata             3.562849
# Toyota          11.619951
# Volkswagen       5.306815
# Volvo           18.802857

# %%
plt.figure(figsize=(20,20))
sns.set(font_scale=0.65)
sns.boxplot(x='Make', y='Price', data=df)

# %% [markdown]
# Since box plots give us the distribution of data in each category, as seen above. We can clearly see that categorical divisions can be made on the 'Make' column. Makers like Maruti, Hyundai and Tata are the cheapest, while in the same dataset there is Lamborghini was costs in excess of 1.2Cr. Therefore category of maker makes a huge difference in the price. Thus, we will include the category of make as a variable.

# %% [markdown]
# Let us explore this further by plotting the mean price for each type of make

# %%
bins = np.linspace(df_make_plot['Price'].min(), df_make_plot['Price'].max(), 15)
fig = plt.figure(figsize=(10,10))
ax1 = fig.add_subplot(1,1,1)
df_make_plot.plot(kind='bar', fontsize=14, ax=ax1)
ax1.set_xlabel('Make', fontsize=20)
ax1.set_ylabel('Price', fontsize=20)
ax1.set_yticks(bins)
ax1.get_legend().remove()
ax1.axhline(y=8, color='r')
ax1.axhline(y=19, color='y')
ax1.axhline(y=35, color='g')
ax1.axhline(y=60, color='b')
ax1.set_title('Means of Prices for Different Makes', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Means of Prices for Different Makes')

# %% [markdown]
# Based on the two plots above and the reputation of car brands, we can make categories for 'Make'. We will be making categories based on the divisions made in the bar chart above.

# %%
make_category = []

for make in df['Make']:
    
    if make in ['Ambassador', 'Chevrolet', 'Datsun', 'Fiat', 'Ford', 'Honda', 'Hyundai', 'Mahindra', 'Maruti', 'Nissan', 'Renault', 'Skoda', 'Tata', 'Volkswagen']:
        make_category.append('Economy')
    
    elif make in ['Force', 'ISUZU', 'Jeep', 'Mitsubishi', 'Toyota', 'Volvo']:
        make_category.append('Mid Segment')
        
    elif make in ['Audi', 'BMW', 'Mercedes-Benz', 'Mini']:
        make_category.append('Upper Segment')
        
    elif make in ['Bentley', 'Jaguar', 'Land Rover', 'Porsche']:
        make_category.append('Luxury')
        
    elif make=='Lamborghini':
        make_category.append('Super Car')

        
df.insert(2, 'Make_Category', make_category)
df.head()
# Out:
#                                Name     Make  Make_Category    Location  Year  \
# 0            Maruti Wagon R LXI CNG   Maruti        Economy      Mumbai  2010
# 1  Hyundai Creta 1.6 CRDi SX Option  Hyundai        Economy        Pune  2015
# 2                      Honda Jazz V    Honda        Economy     Chennai  2011
# 3                 Maruti Ertiga VDI   Maruti        Economy     Chennai  2012
# 4   Audi A4 New 2.0 TDI Multitronic     Audi  Upper Segment  Coimbatore  2013
#
#    Years_Old  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         10              72000       CNG       Manual      First
# 1          5              41000    Diesel       Manual      First
# 2          9              46000    Petrol       Manual      First
# 3          8              87000    Diesel       Manual      First
# 4          7              40670    Diesel    Automatic     Second
#
#    Mileage/unit  Engine (CC) Engine_Class  Power (bhp) Power_Segment  Seats  \
# 0         26.60        998.0        Small        58.16           Low    5.0
# 1         19.67       1582.0        Small       126.20           Low    5.0
# 2         18.20       1199.0        Small        88.70           Low    5.0
# 3         20.77       1248.0        Small        88.76           Low    7.0
# 4         15.20       1968.0       Medium       140.80           Low    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# Now since the 'Make_Category' affects the price, we will encode it and see it correlation with 'Price'.

# %%
df['Make_Category'].replace(to_replace=['Economy', 'Mid Segment', 'Upper Segment', 'Luxury', 'Super Car'], value=[1, 2, 3, 4, 5], inplace=True)
df.head()
# Out:
#                                Name     Make  Make_Category    Location  Year  \
# 0            Maruti Wagon R LXI CNG   Maruti              1      Mumbai  2010
# 1  Hyundai Creta 1.6 CRDi SX Option  Hyundai              1        Pune  2015
# 2                      Honda Jazz V    Honda              1     Chennai  2011
# 3                 Maruti Ertiga VDI   Maruti              1     Chennai  2012
# 4   Audi A4 New 2.0 TDI Multitronic     Audi              3  Coimbatore  2013
#
#    Years_Old  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         10              72000       CNG       Manual      First
# 1          5              41000    Diesel       Manual      First
# 2          9              46000    Petrol       Manual      First
# 3          8              87000    Diesel       Manual      First
# 4          7              40670    Diesel    Automatic     Second
#
#    Mileage/unit  Engine (CC) Engine_Class  Power (bhp) Power_Segment  Seats  \
# 0         26.60        998.0        Small        58.16           Low    5.0
# 1         19.67       1582.0        Small       126.20           Low    5.0
# 2         18.20       1199.0        Small        88.70           Low    5.0
# 3         20.77       1248.0        Small        88.76           Low    7.0
# 4         15.20       1968.0       Medium       140.80           Low    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# Now let's make this a numerical variable so that its correlation with price can be seen.

# %%
df[["Make_Category"]] = df[["Make_Category"]].astype('int')
df.head()
# Out:
#                                Name     Make  Make_Category    Location  Year  \
# 0            Maruti Wagon R LXI CNG   Maruti              1      Mumbai  2010
# 1  Hyundai Creta 1.6 CRDi SX Option  Hyundai              1        Pune  2015
# 2                      Honda Jazz V    Honda              1     Chennai  2011
# 3                 Maruti Ertiga VDI   Maruti              1     Chennai  2012
# 4   Audi A4 New 2.0 TDI Multitronic     Audi              3  Coimbatore  2013
#
#    Years_Old  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0         10              72000       CNG       Manual      First
# 1          5              41000    Diesel       Manual      First
# 2          9              46000    Petrol       Manual      First
# 3          8              87000    Diesel       Manual      First
# 4          7              40670    Diesel    Automatic     Second
#
#    Mileage/unit  Engine (CC) Engine_Class  Power (bhp) Power_Segment  Seats  \
# 0         26.60        998.0        Small        58.16           Low    5.0
# 1         19.67       1582.0        Small       126.20           Low    5.0
# 2         18.20       1199.0        Small        88.70           Low    5.0
# 3         20.77       1248.0        Small        88.76           Low    7.0
# 4         15.20       1968.0       Medium       140.80           Low    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
df.corr()['Price']
# Out:
# Make_Category        0.750095
# Year                 0.302463
# Years_Old           -0.302463
# Kilometers_Driven   -0.009048
# Mileage/unit        -0.333263
# Engine (CC)          0.658130
# Power (bhp)          0.773250
# Seats                0.055178
# Price                1.000000
# Name: Price, dtype: float64

# %% [markdown]
# We will see the correlation of all these variables with 'Price'

# %%
sns.regplot(x='Make_Category',y='Price',data=df)

# %%
sns.regplot(x='Year',y='Price',data=df)

# %%
sns.regplot(x='Years_Old',y='Price',data=df)

# %%
sns.regplot(x='Kilometers_Driven',y='Price',data=df)

# %%
sns.regplot(x='Mileage/unit',y='Price',data=df)

# %%
sns.regplot(x='Engine (CC)',y='Price',data=df)

# %%
sns.regplot(x='Power (bhp)',y='Price',data=df)

# %%
sns.regplot(x='Seats',y='Price',data=df)

# %% [markdown]
# From the regression plots above and the correlation table with 'Price', we can see that 'Year' and 'Years_Old' have the same correlation, therefore we do not need to have 'Years_Old' as it is redundant

# %% [markdown]
# Hence we will drop the 'Years_Old' column

# %%
df.drop('Years_Old', axis=1, inplace=True)

# %% [markdown]
# 'Kilometers_Driven' and 'Seats' have poor correlation with 'Price', therefore we will drop them too, otherwise they may cause overfitting.

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# Based on these inferences, we will create a new data frame which will have the relevant predictor variables, which are:
# - Make_Category
# - Year
# - Mileage/unit
# - Engine (CC)
# - Power (bhp)
# - Price

# %%
df_features = df[['Name', 'Make_Category', 'Year', 'Mileage/unit', 'Engine (CC)', 'Power (bhp)', 'Price']]
df_features
# Out:
#                                   Name  Make_Category  Year  Mileage/unit  \
# 0               Maruti Wagon R LXI CNG              1  2010         26.60
# 1     Hyundai Creta 1.6 CRDi SX Option              1  2015         19.67
# 2                         Honda Jazz V              1  2011         18.20
# 3                    Maruti Ertiga VDI              1  2012         20.77
# 4      Audi A4 New 2.0 TDI Multitronic              3  2013         15.20
# ...                                ...            ...   ...           ...
# 6014                  Maruti Swift VDI              1  2014         28.40
# 6015          Hyundai Xcent 1.1 CRDi S              1  2015         24.40
# 6016             Mahindra Xylo D4 BSIV              1  2012         14.00
# 6017                Maruti Wagon R VXI              1  2013         18.90
# 6018             Chevrolet Beat Diesel              1  2011         25.44
#
#       Engine (CC)  Power (bhp)  Price
# 0           998.0        58.16   1.75
# 1          1582.0       126.20  12.50
# 2          1199.0        88.70   4.50
# 3          1248.0        88.76   6.00
# 4          1968.0       140.80  17.74
# ...           ...          ...    ...
# 6014       1248.0        74.00   4.75
# 6015       1120.0        71.00   4.00
# 6016       2498.0       112.00   2.90
# 6017        998.0        67.10   2.65
# 6018        936.0        57.60   2.50
#
# [5949 rows x 7 columns]

# %% [markdown]
# ## Modelling

# %% [markdown]
# We will train the following models over our dataset and choose the best model based on the evaluation
# - Multiple Linear Regression
# - Random Forest Regression
# - Decision Tree Regression

# %% [markdown]
# Here for training we will perform a train test split and use the same training and testing data to evaluate the model.
# For evaluation we use two metrics:
# - RMSE
# - Cross Validation Score (finally expressed in percentage here)

# %% [markdown]
# ### Train Test Split

# %%
# defining the predictor and target variables
x = df[['Make_Category', 'Year', 'Mileage/unit', 'Engine (CC)', 'Power (bhp)']]
y = df[['Price']]

# %%
# we willl now split the data into training set and testing set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=101)
print('Shape of data:\nx_train: {}\nx_test: {}\ny_train: {}\ny_test: {}'.format(x_train.shape, x_test.shape, y_train.shape, y_test.shape))
# Out:
# Shape of data:
# x_train: (4164, 5)
# x_test: (1785, 5)
# y_train: (4164, 1)
# y_test: (1785, 1)

# %% [markdown]
# ### Multiple Linear Regression

# %% [markdown]
# #### Training

# %% [markdown]
# Now here feature scaling and normalization is not required as we are going to use Multiple Regression, therefore the coefficients for these variables will be set accordingly.

# %% [markdown]
# We will now try to see if Multiple Linear Regression is a good model for the data

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
yhat = lr.predict(x_test)
yhat.shape
# Out:
# (1785, 1)

# %% [markdown]
# #### Evaluation

# %%
score_lr = cross_val_score(lr, x, y, cv=4)

# %%
print('Accuracy Score(%):{}'.format(100*score_lr.mean()))
print('RMSE:{}'.format(np.sqrt(mean_squared_error(yhat, y_test))))
# Out:
# Accuracy Score(%):74.30306926521895
# RMSE:6.164078169275772

# %%
sns.residplot(yhat, y_test)

# %% [markdown]
# We can see that the residue plot for the Linear Regression model is showing a curvature. This implies that Linear Regression is not a good fit for this data. Therefore we will try another model

# %% [markdown]
# ### Random Forest Regression

# %% [markdown]
# #### Training

# %%
rfr = RandomForestRegressor(n_estimators=200)

# %%
rfr.fit(x_train,y_train)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rfr_pred = rfr.predict(x_test)

# %%
plt.figure(figsize = (15,10))
plt.scatter(y_test,rfr_pred)

# %% [markdown]
# #### Evaluation

# %%
score_rfr = cross_val_score(rfr, x, y, cv=4)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)

# %%
print('Accuracy Score(%):{}'.format(100*score_rfr.mean()))
print('RMSE:{}'.format(np.sqrt(mean_squared_error(rfr_pred, y_test))))
# Out:
# Accuracy Score(%):86.8977994110011
# RMSE:4.269063066769496

# %% [markdown]
# ### Decision Tree Regression

# %% [markdown]
# #### Training

# %%
dtree = DecisionTreeRegressor()

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
pred = dtree.predict(x_test)

# %%
plt.figure(figsize = (15,10))
plt.scatter(y_test,pred)

# %% [markdown]
# #### Evaluation

# %%
score_dtree = cross_val_score(dtree, x, y, cv=4)

# %%
print('Accuracy Score(%):{}'.format(100*score_dtree.mean()))
print('RMSE:{}'.format(np.sqrt(mean_squared_error(pred, y_test))))
# Out:
# Accuracy Score(%):78.77965698877661
# RMSE:4.86092667432675

# %% [markdown]
# ### Choice of model

# %% [markdown]
# After evaluating the 3 models, we see that Random Forest Regression has the least RMSE and the highest Cross Validation Score.
# Therefore Random Forest Regression is the best model for the data.

# %% [markdown]
# We will now predict the values of price for the test data given using the same model

# %% [markdown]
# ## Predicting the Prices

# %% [markdown]
# ### Importing the dataset

# %%
test_df = pd.read_excel('Data_Test.xlsx')
test_df.head()
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
# 3             139000    Diesel       Manual      First   23.59 kmpl  1364 CC
# 4              29000    Petrol       Manual      First    18.5 kmpl  1197 CC
#
#        Power  Seats
# 0   58.2 bhp    4.0
# 1   47.3 bhp    5.0
# 2  147.8 bhp    7.0
# 3   null bhp    5.0
# 4  82.85 bhp    5.0

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1234 non-null   object
#  1   Location           1234 non-null   object
#  2   Year               1234 non-null   int64
#  3   Kilometers_Driven  1234 non-null   int64
#  4   Fuel_Type          1234 non-null   object
#  5   Transmission       1234 non-null   object
#  6   Owner_Type         1234 non-null   object
#  7   Mileage            1234 non-null   object
#  8   Engine             1224 non-null   object
#  9   Power              1224 non-null   object
#  10  Seats              1223 non-null   float64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 106.2+ KB

# %% [markdown]
# We will first change the types of a few columns and wrangle the data to the same form as our final training data.

# %% [markdown]
# ### Removing units

# %% [markdown]
# #### Engine

# %%
new_list_engine = []
for engine in test_df['Engine']:
    string=str(engine)
    rep=string.replace('CC','')
    new_list_engine.append(rep)
    
new_list_engine
    
test_df.insert(8, 'Engine (CC)', new_list_engine)
test_df.drop(['Engine'], axis=1, inplace=True)
    
    
test_df.head()
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage  \
# 0              40929       CNG       Manual      First  32.26 km/kg
# 1              54493    Petrol       Manual     Second    24.7 kmpl
# 2              34000    Diesel       Manual      First   13.68 kmpl
# 3             139000    Diesel       Manual      First   23.59 kmpl
# 4              29000    Petrol       Manual      First    18.5 kmpl
#
#   Engine (CC)      Power  Seats
# 0        998    58.2 bhp    4.0
# 1        796    47.3 bhp    5.0
# 2       2393   147.8 bhp    7.0
# 3       1364    null bhp    5.0
# 4       1197   82.85 bhp    5.0

# %% [markdown]
# #### Power

# %%
new_list_power = []
for power in test_df['Power']:
    string=str(power)
    rep=string.replace('bhp','')
    new_list_power.append(rep)
    
new_list_power
    
test_df.insert(9, 'Power (bhp)', new_list_power)
test_df.drop('Power', axis=1, inplace=True)
    
    
test_df.head()
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage  \
# 0              40929       CNG       Manual      First  32.26 km/kg
# 1              54493    Petrol       Manual     Second    24.7 kmpl
# 2              34000    Diesel       Manual      First   13.68 kmpl
# 3             139000    Diesel       Manual      First   23.59 kmpl
# 4              29000    Petrol       Manual      First    18.5 kmpl
#
#   Engine (CC) Power (bhp)  Seats
# 0        998        58.2     4.0
# 1        796        47.3     5.0
# 2       2393       147.8     7.0
# 3       1364        null     5.0
# 4       1197       82.85     5.0

# %% [markdown]
# #### Mileage

# %%
new_list_mileage = []

for mileage in test_df['Mileage']:
    string=str(mileage)
    
    if 'kmpl'in string:
        rep=string.replace('kmpl','')
        new_list_mileage.append(rep)
    
    else:
        rep=string.replace('km/kg','')
        new_list_mileage.append(rep)
                        

        
        
new_list_mileage
    
test_df.insert(7, 'Mileage/unit', new_list_mileage)
test_df.drop('Mileage', axis=1, inplace=True)
    
    
test_df.head()
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 3                       Toyota Etios Liva GD   Hyderabad  2012
# 4                          Hyundai i20 Magna      Mumbai  2014
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type Mileage/unit  \
# 0              40929       CNG       Manual      First       32.26
# 1              54493    Petrol       Manual     Second        24.7
# 2              34000    Diesel       Manual      First       13.68
# 3             139000    Diesel       Manual      First       23.59
# 4              29000    Petrol       Manual      First        18.5
#
#   Engine (CC) Power (bhp)  Seats
# 0        998        58.2     4.0
# 1        796        47.3     5.0
# 2       2393       147.8     7.0
# 3       1364        null     5.0
# 4       1197       82.85     5.0

# %% [markdown]
# ### Changing type

# %%
test_df[["Mileage/unit"]] = test_df[["Mileage/unit"]].astype("float")
test_df[["Engine (CC)"]] = test_df[["Engine (CC)"]].astype("float")
test_df["Power (bhp)"] = pd.to_numeric(test_df["Power (bhp)"], errors='coerce')
test_df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage/unit         float64
# Engine (CC)          float64
# Power (bhp)          float64
# Seats                float64
# dtype: object

# %% [markdown]
# ### Dealing missing values

# %%
test_df.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage/unit          0
# Engine (CC)          10
# Power (bhp)          32
# Seats                11
# dtype: int64

# %% [markdown]
# Here we drop the missing values as we are given the test data. Replacing values is not upto our discretion.
# Though we have to remove the genuine outliers

# %%
test_df.dropna(inplace=True)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1201 entries, 0 to 1233
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               1201 non-null   object
#  1   Location           1201 non-null   object
#  2   Year               1201 non-null   int64
#  3   Kilometers_Driven  1201 non-null   int64
#  4   Fuel_Type          1201 non-null   object
#  5   Transmission       1201 non-null   object
#  6   Owner_Type         1201 non-null   object
#  7   Mileage/unit       1201 non-null   float64
#  8   Engine (CC)        1201 non-null   float64
#  9   Power (bhp)        1201 non-null   float64
#  10  Seats              1201 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 112.6+ KB

# %% [markdown]
# ### Removing outliers

# %%
sns.boxplot(x='Mileage/unit',data=test_df)

# %%
test_df= test_df[test_df['Mileage/unit']>=5]

# %%
sns.boxplot(x='Engine (CC)',data=test_df)

# %%
sns.boxplot(x='Power (bhp)',data=test_df)

# %%
sns.boxplot(x='Seats',data=test_df)

# %%
test_df[test_df['Seats']>9]
# Out:
#                                       Name   Location  Year  \
# 223             Tata Sumo EX 10/7 Str BSII    Chennai  2015
# 269  Chevrolet Tavera LS B3 10 Seats BSIII  Hyderabad  2005
# 856                    Toyota Qualis FS B3       Pune  2002
#
#      Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage/unit  \
# 223             196000    Diesel       Manual     Second          12.2
# 269             150000    Diesel       Manual     Second          14.8
# 856             119613    Diesel       Manual     Second          13.1
#
#      Engine (CC)  Power (bhp)  Seats
# 223       1948.0         68.0   10.0
# 269       2499.0         80.0   10.0
# 856       2446.0         75.0   10.0

# %% [markdown]
# These values are correct and not outliers

# %% [markdown]
# ### Creating the same columns as chosen in feature selection

# %%
make = []
for name in test_df['Name']:
    make.append(name.split(' ')[0])

test_df.insert(1, 'Make', make)

# %%
test_df.head()
# Out:
#                                         Name      Make    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG    Maruti       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI    Maruti  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT    Toyota      Mumbai  2017
# 4                          Hyundai i20 Magna   Hyundai      Mumbai  2014
# 5                     Mahindra XUV500 W8 2WD  Mahindra  Coimbatore  2016
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage/unit  \
# 0              40929       CNG       Manual      First         32.26
# 1              54493    Petrol       Manual     Second         24.70
# 2              34000    Diesel       Manual      First         13.68
# 4              29000    Petrol       Manual      First         18.50
# 5              85609    Diesel       Manual     Second         16.00
#
#    Engine (CC)  Power (bhp)  Seats
# 0        998.0        58.20    4.0
# 1        796.0        47.30    5.0
# 2       2393.0       147.80    7.0
# 4       1197.0        82.85    5.0
# 5       2179.0       140.00    7.0

# %%
test_df['Make'].unique()
# Out:
# array(['Maruti', 'Toyota', 'Hyundai', 'Mahindra', 'Honda', 'Audi',
#        'Nissan', 'BMW', 'Ford', 'Skoda', 'Volkswagen', 'Mitsubishi',
#        'Mercedes-Benz', 'Tata', 'Chevrolet', 'Datsun', 'Jaguar', 'Fiat',
#        'Renault', 'Mini', 'Bentley', 'Land', 'Volvo', 'Isuzu', 'Jeep',
#        'Porsche', 'ISUZU', 'OpelCorsa'], dtype=object)

# %%
test_df['Make'].replace('Land','Land Rover',inplace=True)
test_df['Make'].replace('Isuzu', 'ISUZU',inplace=True)

# %%
test_df['Make'].nunique()
# Out:
# 27

# %% [markdown]
# Now since the makers in this dataset are different, we will see which car makers are common and which are exclusive to te new dataset.

# %%
exclusive = []
common = []

for make in test_df['Make'].unique():
    
    if make in df['Make'].unique():
        common.append(make)
    
    else:
        exclusive.append(make)
        

print('The common makes are: ',common,'\n')
print('The exclusive makes are: ',exclusive)
# Out:
# The common makes are:  ['Maruti', 'Toyota', 'Hyundai', 'Mahindra', 'Honda', 'Audi', 'Nissan', 'BMW', 'Ford', 'Skoda', 'Volkswagen', 'Mitsubishi', 'Mercedes-Benz', 'Tata', 'Chevrolet', 'Datsun', 'Jaguar', 'Fiat', 'Renault', 'Mini', 'Bentley', 'Land Rover', 'Volvo', 'ISUZU', 'Jeep', 'Porsche']
#
# The exclusive makes are:  ['OpelCorsa']

# %% [markdown]
# We see that 'OpelCorsa' is a make which is not there in the training datset. Therefore, we must classify 'OpelCorsa' in a make category, as 'Make_Category' is a variable used in our model.

# %% [markdown]
# For this we will use our domain knowledge about cars as well as perform analysis with other variables to see which category it lies in

# %%
sns.regplot(x='Make_Category', y='Engine (CC)', data=df)

# %%
sns.regplot(x='Make_Category', y='Power (bhp)', data=df)

# %% [markdown]
# From these plots we can see that there is a positive and strong correlation between the make category and the Engine Size and the Power. Therefore, to find out the make_category of 'OpelCorsa' we should compare its Engine size and Power to the other categories

# %%
test_df[test_df['Make']=='OpelCorsa']
# Out:
#                   Name       Make   Location  Year  Kilometers_Driven  \
# 1048  OpelCorsa 1.4Gsi  OpelCorsa  Hyderabad  2005              50000
#
#      Fuel_Type Transmission Owner_Type  Mileage/unit  Engine (CC)  \
# 1048    Petrol       Manual     Second          14.2       1389.0
#
#       Power (bhp)  Seats
# 1048         88.0    5.0

# %% [markdown]
# There is only one car with the make 'OpelCorsa'. We will compare its engine size and power to other makes and see which category it is closest to.

# %%
df_make_comp = df[['Make_Category', 'Engine (CC)', 'Power (bhp)']]
df_make_comp = df_make_comp.groupby('Make_Category').mean()
df_make_comp
# Out:
#                Engine (CC)  Power (bhp)
# Make_Category
# 1              1393.532582    92.335478
# 2              2305.436059   132.693166
# 3              2302.505995   196.109077
# 4              2741.818182   233.839000
# 5              5204.000000   560.000000

# %% [markdown]
# Now through bar plots we will compare the average values of Engine size and Power of different Make categories to the Engine size and Power of OpelCorsa

# %%
fig_test = plt.figure(figsize=(15,15))
axa = fig_test.add_subplot(211)
axb = fig_test.add_subplot(212)
df_make_comp['Engine (CC)'].plot(kind='bar', fontsize=25, ax=axa)
df_make_comp['Power (bhp)'].plot(kind='bar', fontsize=25, ax=axb)
axa.axhline(y=1389, color='r')
axb.axhline(y=88, color='r')
axa.set_title('Comparison of Engine Capacity of OpelCorsa to the mean of other Make Categories', fontsize=25)
axb.set_title('Comparison of Power of OpelCorsa to the mean of other Make Categories', fontsize=25)
axa.annotate('OpelCorsa', xy=(-0.5,1500), xycoords='data', fontsize=20)
axb.annotate('OpelCorsa', xy=(-0.5,100), xycoords='data', fontsize=20)
axa.set_ylabel('Mean Engine(CC)', fontsize=25)
axb.set_ylabel('Mean Power(bhp)', fontsize=25)
axb.set_xlabel('Make_Category', fontsize=25)
# Out:
# Text(0.5, 0, 'Make_Category')

# %% [markdown]
# We can clearly see that the values of engine size and power are close to the mean of the class 1 make, therefore it lies in the category 1 which corresponds to Economy. Also after researching the prices of OpelCorsa cars, we can confirm that it lies in th Economy class.

# %%
make_category_test = []

for make in test_df['Make']:
    
    if make in ['Ambassador', 'Chevrolet', 'Datsun', 'Fiat', 'Ford', 'Honda', 'Hyundai', 'Mahindra', 'Maruti', 'Nissan', 'Renault', 'Skoda', 'Tata', 'Volkswagen', 'OpelCorsa']:
        make_category_test.append('Economy')
    
    elif make in ['Force', 'ISUZU', 'Jeep', 'Mitsubishi', 'Toyota', 'Volvo']:
        make_category_test.append('Mid Segment')
        
    elif make in ['Audi', 'BMW', 'Mercedes-Benz', 'Mini']:
        make_category_test.append('Upper Segment')
        
    elif make in ['Bentley', 'Jaguar', 'Land Rover', 'Porsche']:
        make_category_test.append('Luxury')
        
    elif make=='Lamborghini':
        make_category_test.append('Super Car')

        
test_df.insert(2, 'Make_Category', make_category_test)

# %%
test_df.head()
# Out:
#                                         Name      Make Make_Category  \
# 0                    Maruti Alto K10 LXI CNG    Maruti       Economy
# 1              Maruti Alto 800 2016-2019 LXI    Maruti       Economy
# 2  Toyota Innova Crysta Touring Sport 2.4 MT    Toyota   Mid Segment
# 4                          Hyundai i20 Magna   Hyundai       Economy
# 5                     Mahindra XUV500 W8 2WD  Mahindra       Economy
#
#      Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0       Delhi  2014              40929       CNG       Manual      First
# 1  Coimbatore  2013              54493    Petrol       Manual     Second
# 2      Mumbai  2017              34000    Diesel       Manual      First
# 4      Mumbai  2014              29000    Petrol       Manual      First
# 5  Coimbatore  2016              85609    Diesel       Manual     Second
#
#    Mileage/unit  Engine (CC)  Power (bhp)  Seats
# 0         32.26        998.0        58.20    4.0
# 1         24.70        796.0        47.30    5.0
# 2         13.68       2393.0       147.80    7.0
# 4         18.50       1197.0        82.85    5.0
# 5         16.00       2179.0       140.00    7.0

# %%
test_df['Make_Category'].replace(to_replace=['Economy', 'Mid Segment', 'Upper Segment', 'Luxury', 'Super Car'], value=[1, 2, 3, 4, 5], inplace=True)
test_df[["Make_Category"]] = test_df[["Make_Category"]].astype('int')
test_df.head()
# Out:
#                                         Name      Make  Make_Category  \
# 0                    Maruti Alto K10 LXI CNG    Maruti              1
# 1              Maruti Alto 800 2016-2019 LXI    Maruti              1
# 2  Toyota Innova Crysta Touring Sport 2.4 MT    Toyota              2
# 4                          Hyundai i20 Magna   Hyundai              1
# 5                     Mahindra XUV500 W8 2WD  Mahindra              1
#
#      Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0       Delhi  2014              40929       CNG       Manual      First
# 1  Coimbatore  2013              54493    Petrol       Manual     Second
# 2      Mumbai  2017              34000    Diesel       Manual      First
# 4      Mumbai  2014              29000    Petrol       Manual      First
# 5  Coimbatore  2016              85609    Diesel       Manual     Second
#
#    Mileage/unit  Engine (CC)  Power (bhp)  Seats
# 0         32.26        998.0        58.20    4.0
# 1         24.70        796.0        47.30    5.0
# 2         13.68       2393.0       147.80    7.0
# 4         18.50       1197.0        82.85    5.0
# 5         16.00       2179.0       140.00    7.0

# %% [markdown]
# Now our test dataset is ready to apply the model on. We can now predict the prices for these cars.

# %% [markdown]
# ### Predicting

# %% [markdown]
# We will now fit the model on the testing data given

# %%
X = test_df[['Make_Category', 'Year', 'Mileage/unit', 'Engine (CC)', 'Power (bhp)']]

# %%
predicted_price = rfr.predict(X)

# %%
test_df['Predicted Price'] = predicted_price

# %%
test_df['Predicted Price'] = test_df['Predicted Price'].round(2)

# %%
test_df.drop(['Make', 'Make_Category'], axis=1, inplace=True)

# %% [markdown]
# ## Final Dataset With the Predicted Prices

# %% [markdown]
# We were given this dataset to predict the prices for. The original dataset along with the predicted prices are given below.

# %%
test_df
# Out:
#                                                    Name    Location  Year  \
# 0                               Maruti Alto K10 LXI CNG       Delhi  2014
# 1                         Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2             Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
# 4                                     Hyundai i20 Magna      Mumbai  2014
# 5                                Mahindra XUV500 W8 2WD  Coimbatore  2016
# ...                                                 ...         ...   ...
# 1229                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 1230                             Volkswagen Polo GT TSI      Mumbai  2015
# 1231                             Nissan Micra Diesel XV     Kolkata  2012
# 1232                             Volkswagen Polo GT TSI        Pune  2013
# 1233  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage/unit  \
# 0                 40929       CNG       Manual      First         32.26
# 1                 54493    Petrol       Manual     Second         24.70
# 2                 34000    Diesel       Manual      First         13.68
# 4                 29000    Petrol       Manual      First         18.50
# 5                 85609    Diesel       Manual     Second         16.00
# ...                 ...       ...          ...        ...           ...
# 1229              89411    Diesel       Manual      First         20.54
# 1230              59000    Petrol    Automatic      First         17.21
# 1231              28000    Diesel       Manual      First         23.08
# 1232              52262    Petrol    Automatic      Third         17.20
# 1233              72443    Diesel    Automatic      First         10.00
#
#       Engine (CC)  Power (bhp)  Seats  Predicted Price
# 0           998.0        58.20    4.0             3.43
# 1           796.0        47.30    5.0             2.11
# 2          2393.0       147.80    7.0            17.99
# 4          1197.0        82.85    5.0             4.87
# 5          2179.0       140.00    7.0            13.37
# ...           ...          ...    ...              ...
# 1229       1598.0       103.60    5.0             4.17
# 1230       1197.0       103.60    5.0             6.48
# 1231       1461.0        63.10    5.0             3.05
# 1232       1197.0       103.60    5.0             4.41
# 1233       2148.0       170.00    5.0            23.11
#
# [1195 rows x 12 columns]

# %% [markdown]
# ### This concludes the internship's major project. I would like to thank the instructors and support team from Verzeo for their guidance. The concepts taught by them and their efforts solidified the interest for Data Science in me.
